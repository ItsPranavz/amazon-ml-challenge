# %%
import os
import cv2
import base64
import requests
import numpy as np
import pandas as pd
from io import BytesIO
from matplotlib import pyplot as plt
from IPython.display import display, HTML

# %%
# Function to sharpen the image
def sharpen_image(img):
    kernel = np.array([[ 0, -1,  0],
                       [-1, 5, -1],
                       [ 0, -1,  0]])
    sharpened = cv2.filter2D(img, -1, kernel)
    return sharpened

# Function to resize the image (upscale to twice the original size)
def upscale_image(img, scale=2):
    width = int(img.shape[1] * scale)
    height = int(img.shape[0] * scale)
    resized = cv2.resize(img, (width, height), interpolation=cv2.INTER_CUBIC)
    return resized

# %%
def preprocess_images(input_base_folder='../../data/segments/', output_base_folder='../../data/preprocessed/'):
    # Create the base preprocessed folder if it doesn't exist
    if not os.path.exists(output_base_folder):
        os.makedirs(output_base_folder)

    # Loop through each folder in the base input directory
    for folder_name in os.listdir(input_base_folder):
        folder_path = os.path.join(input_base_folder, folder_name)

        # Check if it's a directory (folder)
        if os.path.isdir(folder_path):
            # Define corresponding output folder for preprocessed images
            output_folder = os.path.join(output_base_folder, folder_name)

            # Create the output folder if it doesn't exist
            os.makedirs(output_folder, exist_ok=True)

            # Path to image crops inside the current folder
            image_crops_path = os.path.join(folder_path, 'image_crops')

            # Check if image_crops folder exists in the current folder
            if os.path.exists(image_crops_path):
                # Process each image in the 'image_crops' folder
                for filename in os.listdir(image_crops_path):
                    if filename.endswith('.png'):  # Only process PNG images
                        image_path = os.path.join(image_crops_path, filename)
                        img = cv2.imread(image_path)

                        # Apply preprocessing steps
                        img = upscale_image(img)  # Apply upscaling
                        img = sharpen_image(img)  # Apply sharpening

                        # Save the processed image in the corresponding output folder
                        save_path = os.path.join(output_folder, filename)
                        cv2.imwrite(save_path, img)
                        print(f"Processed and saved: {save_path}")

# Example usage
preprocess_images(input_base_folder='../../data/segments/', output_base_folder='../../data/preprocessed/')
# Out:
# Processed and saved: ../../data/preprocessed/0\crop_0.png
# Processed and saved: ../../data/preprocessed/0\crop_1.png
# Processed and saved: ../../data/preprocessed/0\crop_10.png
# Processed and saved: ../../data/preprocessed/0\crop_11.png
# Processed and saved: ../../data/preprocessed/0\crop_12.png
# Processed and saved: ../../data/preprocessed/0\crop_13.png
# Processed and saved: ../../data/preprocessed/0\crop_14.png
# Processed and saved: ../../data/preprocessed/0\crop_15.png
# Processed and saved: ../../data/preprocessed/0\crop_16.png
# Processed and saved: ../../data/preprocessed/0\crop_17.png
# Processed and saved: ../../data/preprocessed/0\crop_18.png
# Processed and saved: ../../data/preprocessed/0\crop_19.png
# Processed and saved: ../../data/preprocessed/0\crop_2.png
# Processed and saved: ../../data/preprocessed/0\crop_20.png
# Processed and saved: ../../data/preprocessed/0\crop_21.png
# Processed and saved: ../../data/preprocessed/0\crop_22.png
# Processed and saved: ../../data/preprocessed/0\crop_23.png
# Processed and saved: ../../data/preprocessed/0\crop_24.png
# Processed and saved: ../../data/preprocessed/0\crop_3.png
# Processed and saved: ../../data/preprocessed/0\crop_4.png
# Processed and saved: ../../data/preprocessed/0\crop_5.png
# Processed and saved: ../../data/preprocessed/0\crop_6.png
# Processed and saved: ../../data/preprocessed/0\crop_7.png
# Processed and saved: ../../data/preprocessed/0\crop_8.png
# Processed and saved: ../../data/preprocessed/0\crop_9.png
# Processed and saved: ../../data/preprocessed/1\crop_0.png
# Processed and saved: ../../data/preprocessed/1\crop_1.png
# Processed and saved: ../../data/preprocessed/1\crop_10.png
# Processed and saved: ../../data/preprocessed/1\crop_11.png
# Processed and saved: ../../data/preprocessed/1\crop_12.png
# Processed and saved: ../../data/preprocessed/1\crop_13.png
# Processed and saved: ../../data/preprocessed/1\crop_14.png
# Processed and saved: ../../data/preprocessed/1\crop_15.png
# Processed and saved: ../../data/preprocessed/1\crop_16.png
# Processed and saved: ../../data/preprocessed/1\crop_17.png
# Processed and saved: ../../data/preprocessed/1\crop_18.png
# Processed and saved: ../../data/preprocessed/1\crop_19.png
# Processed and saved: ../../data/preprocessed/1\crop_2.png
# Processed and saved: ../../data/preprocessed/1\crop_3.png
# Processed and saved: ../../data/preprocessed/1\crop_4.png
# Processed and saved: ../../data/preprocessed/1\crop_5.png
# Processed and saved: ../../data/preprocessed/1\crop_6.png
# Processed and saved: ../../data/preprocessed/1\crop_7.png
# Processed and saved: ../../data/preprocessed/1\crop_8.png
# Processed and saved: ../../data/preprocessed/1\crop_9.png
# Processed and saved: ../../data/preprocessed/10\crop_0.png
# Processed and saved: ../../data/preprocessed/10\crop_1.png
# Processed and saved: ../../data/preprocessed/10\crop_2.png
# Processed and saved: ../../data/preprocessed/10\crop_3.png
# Processed and saved: ../../data/preprocessed/10\crop_4.png
# Processed and saved: ../../data/preprocessed/10\crop_5.png
# Processed and saved: ../../data/preprocessed/10\crop_6.png
# Processed and saved: ../../data/preprocessed/11\crop_0.png
# Processed and saved: ../../data/preprocessed/11\crop_1.png
# Processed and saved: ../../data/preprocessed/11\crop_10.png
# Processed and saved: ../../data/preprocessed/11\crop_11.png
# Processed and saved: ../../data/preprocessed/11\crop_12.png
# Processed and saved: ../../data/preprocessed/11\crop_13.png
# Processed and saved: ../../data/preprocessed/11\crop_14.png
# Processed and saved: ../../data/preprocessed/11\crop_15.png
# Processed and saved: ../../data/preprocessed/11\crop_16.png
# Processed and saved: ../../data/preprocessed/11\crop_17.png
# Processed and saved: ../../data/preprocessed/11\crop_18.png
# Processed and saved: ../../data/preprocessed/11\crop_19.png
# Processed and saved: ../../data/preprocessed/11\crop_2.png
# Processed and saved: ../../data/preprocessed/11\crop_20.png
# Processed and saved: ../../data/preprocessed/11\crop_21.png
# Processed and saved: ../../data/preprocessed/11\crop_3.png
# Processed and saved: ../../data/preprocessed/11\crop_4.png
# Processed and saved: ../../data/preprocessed/11\crop_5.png
# Processed and saved: ../../data/preprocessed/11\crop_6.png
# Processed and saved: ../../data/preprocessed/11\crop_7.png
# Processed and saved: ../../data/preprocessed/11\crop_8.png
# Processed and saved: ../../data/preprocessed/11\crop_9.png
# Processed and saved: ../../data/preprocessed/12\crop_0.png
# Processed and saved: ../../data/preprocessed/12\crop_1.png
# Processed and saved: ../../data/preprocessed/12\crop_10.png
# Processed and saved: ../../data/preprocessed/12\crop_11.png
# Processed and saved: ../../data/preprocessed/12\crop_12.png
# Processed and saved: ../../data/preprocessed/12\crop_13.png
# Processed and saved: ../../data/preprocessed/12\crop_14.png
# Processed and saved: ../../data/preprocessed/12\crop_15.png
# Processed and saved: ../../data/preprocessed/12\crop_16.png
# Processed and saved: ../../data/preprocessed/12\crop_17.png
# Processed and saved: ../../data/preprocessed/12\crop_18.png
# Processed and saved: ../../data/preprocessed/12\crop_19.png
# Processed and saved: ../../data/preprocessed/12\crop_2.png
# Processed and saved: ../../data/preprocessed/12\crop_20.png
# Processed and saved: ../../data/preprocessed/12\crop_21.png
# Processed and saved: ../../data/preprocessed/12\crop_22.png
# Processed and saved: ../../data/preprocessed/12\crop_23.png
# Processed and saved: ../../data/preprocessed/12\crop_24.png
# Processed and saved: ../../data/preprocessed/12\crop_25.png
# Processed and saved: ../../data/preprocessed/12\crop_26.png
# Processed and saved: ../../data/preprocessed/12\crop_27.png
# Processed and saved: ../../data/preprocessed/12\crop_28.png
# Processed and saved: ../../data/preprocessed/12\crop_29.png
# Processed and saved: ../../data/preprocessed/12\crop_3.png
# Processed and saved: ../../data/preprocessed/12\crop_30.png
# Processed and saved: ../../data/preprocessed/12\crop_31.png
# Processed and saved: ../../data/preprocessed/12\crop_32.png
# Processed and saved: ../../data/preprocessed/12\crop_33.png
# Processed and saved: ../../data/preprocessed/12\crop_34.png
# Processed and saved: ../../data/preprocessed/12\crop_35.png
# Processed and saved: ../../data/preprocessed/12\crop_36.png
# Processed and saved: ../../data/preprocessed/12\crop_37.png
# Processed and saved: ../../data/preprocessed/12\crop_38.png
# Processed and saved: ../../data/preprocessed/12\crop_4.png
# Processed and saved: ../../data/preprocessed/12\crop_5.png
# Processed and saved: ../../data/preprocessed/12\crop_6.png
# Processed and saved: ../../data/preprocessed/12\crop_7.png
# Processed and saved: ../../data/preprocessed/12\crop_8.png
# Processed and saved: ../../data/preprocessed/12\crop_9.png
# Processed and saved: ../../data/preprocessed/13\crop_0.png
# Processed and saved: ../../data/preprocessed/13\crop_1.png
# Processed and saved: ../../data/preprocessed/13\crop_10.png
# Processed and saved: ../../data/preprocessed/13\crop_11.png
# Processed and saved: ../../data/preprocessed/13\crop_12.png
# Processed and saved: ../../data/preprocessed/13\crop_13.png
# Processed and saved: ../../data/preprocessed/13\crop_14.png
# Processed and saved: ../../data/preprocessed/13\crop_15.png
# Processed and saved: ../../data/preprocessed/13\crop_16.png
# Processed and saved: ../../data/preprocessed/13\crop_17.png
# Processed and saved: ../../data/preprocessed/13\crop_18.png
# Processed and saved: ../../data/preprocessed/13\crop_19.png
# Processed and saved: ../../data/preprocessed/13\crop_2.png
# Processed and saved: ../../data/preprocessed/13\crop_3.png
# Processed and saved: ../../data/preprocessed/13\crop_4.png
# Processed and saved: ../../data/preprocessed/13\crop_5.png
# Processed and saved: ../../data/preprocessed/13\crop_6.png
# Processed and saved: ../../data/preprocessed/13\crop_7.png
# Processed and saved: ../../data/preprocessed/13\crop_8.png
# Processed and saved: ../../data/preprocessed/13\crop_9.png
# Processed and saved: ../../data/preprocessed/14\crop_0.png
# Processed and saved: ../../data/preprocessed/14\crop_1.png
# Processed and saved: ../../data/preprocessed/14\crop_10.png
# Processed and saved: ../../data/preprocessed/14\crop_100.png
# Processed and saved: ../../data/preprocessed/14\crop_101.png
# Processed and saved: ../../data/preprocessed/14\crop_102.png
# Processed and saved: ../../data/preprocessed/14\crop_103.png
# Processed and saved: ../../data/preprocessed/14\crop_104.png
# Processed and saved: ../../data/preprocessed/14\crop_105.png
# Processed and saved: ../../data/preprocessed/14\crop_106.png
# Processed and saved: ../../data/preprocessed/14\crop_107.png
# Processed and saved: ../../data/preprocessed/14\crop_108.png
# Processed and saved: ../../data/preprocessed/14\crop_109.png
# Processed and saved: ../../data/preprocessed/14\crop_11.png
# Processed and saved: ../../data/preprocessed/14\crop_110.png
# Processed and saved: ../../data/preprocessed/14\crop_111.png
# Processed and saved: ../../data/preprocessed/14\crop_112.png
# Processed and saved: ../../data/preprocessed/14\crop_113.png
# Processed and saved: ../../data/preprocessed/14\crop_114.png
# Processed and saved: ../../data/preprocessed/14\crop_115.png
# Processed and saved: ../../data/preprocessed/14\crop_116.png
# Processed and saved: ../../data/preprocessed/14\crop_117.png
# Processed and saved: ../../data/preprocessed/14\crop_118.png
# Processed and saved: ../../data/preprocessed/14\crop_119.png
# Processed and saved: ../../data/preprocessed/14\crop_12.png
# Processed and saved: ../../data/preprocessed/14\crop_120.png
# Processed and saved: ../../data/preprocessed/14\crop_121.png
# Processed and saved: ../../data/preprocessed/14\crop_122.png
# Processed and saved: ../../data/preprocessed/14\crop_123.png
# Processed and saved: ../../data/preprocessed/14\crop_124.png
# Processed and saved: ../../data/preprocessed/14\crop_125.png
# Processed and saved: ../../data/preprocessed/14\crop_126.png
# Processed and saved: ../../data/preprocessed/14\crop_127.png
# Processed and saved: ../../data/preprocessed/14\crop_128.png
# Processed and saved: ../../data/preprocessed/14\crop_13.png
# Processed and saved: ../../data/preprocessed/14\crop_14.png
# Processed and saved: ../../data/preprocessed/14\crop_15.png
# Processed and saved: ../../data/preprocessed/14\crop_16.png
# Processed and saved: ../../data/preprocessed/14\crop_17.png
# Processed and saved: ../../data/preprocessed/14\crop_18.png
# Processed and saved: ../../data/preprocessed/14\crop_19.png
# Processed and saved: ../../data/preprocessed/14\crop_2.png
# Processed and saved: ../../data/preprocessed/14\crop_20.png
# Processed and saved: ../../data/preprocessed/14\crop_21.png
# Processed and saved: ../../data/preprocessed/14\crop_22.png
# Processed and saved: ../../data/preprocessed/14\crop_23.png
# Processed and saved: ../../data/preprocessed/14\crop_24.png
# Processed and saved: ../../data/preprocessed/14\crop_25.png
# Processed and saved: ../../data/preprocessed/14\crop_26.png
# Processed and saved: ../../data/preprocessed/14\crop_27.png
# Processed and saved: ../../data/preprocessed/14\crop_28.png
# Processed and saved: ../../data/preprocessed/14\crop_29.png
# Processed and saved: ../../data/preprocessed/14\crop_3.png
# Processed and saved: ../../data/preprocessed/14\crop_30.png
# Processed and saved: ../../data/preprocessed/14\crop_31.png
# Processed and saved: ../../data/preprocessed/14\crop_32.png
# Processed and saved: ../../data/preprocessed/14\crop_33.png
# Processed and saved: ../../data/preprocessed/14\crop_34.png
# Processed and saved: ../../data/preprocessed/14\crop_35.png
# Processed and saved: ../../data/preprocessed/14\crop_36.png
# Processed and saved: ../../data/preprocessed/14\crop_37.png
# Processed and saved: ../../data/preprocessed/14\crop_38.png
# Processed and saved: ../../data/preprocessed/14\crop_39.png
# Processed and saved: ../../data/preprocessed/14\crop_4.png
# Processed and saved: ../../data/preprocessed/14\crop_40.png
# Processed and saved: ../../data/preprocessed/14\crop_41.png
# Processed and saved: ../../data/preprocessed/14\crop_42.png
# Processed and saved: ../../data/preprocessed/14\crop_43.png
# Processed and saved: ../../data/preprocessed/14\crop_44.png
# Processed and saved: ../../data/preprocessed/14\crop_45.png
# Processed and saved: ../../data/preprocessed/14\crop_46.png
# Processed and saved: ../../data/preprocessed/14\crop_47.png
# Processed and saved: ../../data/preprocessed/14\crop_48.png
# Processed and saved: ../../data/preprocessed/14\crop_49.png
# Processed and saved: ../../data/preprocessed/14\crop_5.png
# Processed and saved: ../../data/preprocessed/14\crop_50.png
# Processed and saved: ../../data/preprocessed/14\crop_51.png
# Processed and saved: ../../data/preprocessed/14\crop_52.png
# Processed and saved: ../../data/preprocessed/14\crop_53.png
# Processed and saved: ../../data/preprocessed/14\crop_54.png
# Processed and saved: ../../data/preprocessed/14\crop_55.png
# Processed and saved: ../../data/preprocessed/14\crop_56.png
# Processed and saved: ../../data/preprocessed/14\crop_57.png
# Processed and saved: ../../data/preprocessed/14\crop_58.png
# Processed and saved: ../../data/preprocessed/14\crop_59.png
# Processed and saved: ../../data/preprocessed/14\crop_6.png
# Processed and saved: ../../data/preprocessed/14\crop_60.png
# Processed and saved: ../../data/preprocessed/14\crop_61.png
# Processed and saved: ../../data/preprocessed/14\crop_62.png
# Processed and saved: ../../data/preprocessed/14\crop_63.png
# Processed and saved: ../../data/preprocessed/14\crop_64.png
# Processed and saved: ../../data/preprocessed/14\crop_65.png
# Processed and saved: ../../data/preprocessed/14\crop_66.png
# Processed and saved: ../../data/preprocessed/14\crop_67.png
# Processed and saved: ../../data/preprocessed/14\crop_68.png
# Processed and saved: ../../data/preprocessed/14\crop_69.png
# Processed and saved: ../../data/preprocessed/14\crop_7.png
# Processed and saved: ../../data/preprocessed/14\crop_70.png
# Processed and saved: ../../data/preprocessed/14\crop_71.png
# Processed and saved: ../../data/preprocessed/14\crop_72.png
# Processed and saved: ../../data/preprocessed/14\crop_73.png
# Processed and saved: ../../data/preprocessed/14\crop_74.png
# Processed and saved: ../../data/preprocessed/14\crop_75.png
# Processed and saved: ../../data/preprocessed/14\crop_76.png
# Processed and saved: ../../data/preprocessed/14\crop_77.png
# Processed and saved: ../../data/preprocessed/14\crop_78.png
# Processed and saved: ../../data/preprocessed/14\crop_79.png
# Processed and saved: ../../data/preprocessed/14\crop_8.png
# Processed and saved: ../../data/preprocessed/14\crop_80.png
# Processed and saved: ../../data/preprocessed/14\crop_81.png
# Processed and saved: ../../data/preprocessed/14\crop_82.png
# Processed and saved: ../../data/preprocessed/14\crop_83.png
# Processed and saved: ../../data/preprocessed/14\crop_84.png
# Processed and saved: ../../data/preprocessed/14\crop_85.png
# Processed and saved: ../../data/preprocessed/14\crop_86.png
# Processed and saved: ../../data/preprocessed/14\crop_87.png
# Processed and saved: ../../data/preprocessed/14\crop_88.png
# Processed and saved: ../../data/preprocessed/14\crop_89.png
# Processed and saved: ../../data/preprocessed/14\crop_9.png
# Processed and saved: ../../data/preprocessed/14\crop_90.png
# Processed and saved: ../../data/preprocessed/14\crop_91.png
# Processed and saved: ../../data/preprocessed/14\crop_92.png
# Processed and saved: ../../data/preprocessed/14\crop_93.png
# Processed and saved: ../../data/preprocessed/14\crop_94.png
# Processed and saved: ../../data/preprocessed/14\crop_95.png
# Processed and saved: ../../data/preprocessed/14\crop_96.png
# Processed and saved: ../../data/preprocessed/14\crop_97.png
# Processed and saved: ../../data/preprocessed/14\crop_98.png
# Processed and saved: ../../data/preprocessed/14\crop_99.png
# Processed and saved: ../../data/preprocessed/15\crop_0.png
# Processed and saved: ../../data/preprocessed/15\crop_1.png
# Processed and saved: ../../data/preprocessed/15\crop_10.png
# Processed and saved: ../../data/preprocessed/15\crop_11.png
# Processed and saved: ../../data/preprocessed/15\crop_12.png
# Processed and saved: ../../data/preprocessed/15\crop_13.png
# Processed and saved: ../../data/preprocessed/15\crop_14.png
# Processed and saved: ../../data/preprocessed/15\crop_15.png
# Processed and saved: ../../data/preprocessed/15\crop_16.png
# Processed and saved: ../../data/preprocessed/15\crop_17.png
# Processed and saved: ../../data/preprocessed/15\crop_18.png
# Processed and saved: ../../data/preprocessed/15\crop_19.png
# Processed and saved: ../../data/preprocessed/15\crop_2.png
# Processed and saved: ../../data/preprocessed/15\crop_20.png
# Processed and saved: ../../data/preprocessed/15\crop_21.png
# Processed and saved: ../../data/preprocessed/15\crop_22.png
# Processed and saved: ../../data/preprocessed/15\crop_23.png
# Processed and saved: ../../data/preprocessed/15\crop_24.png
# Processed and saved: ../../data/preprocessed/15\crop_25.png
# Processed and saved: ../../data/preprocessed/15\crop_26.png
# Processed and saved: ../../data/preprocessed/15\crop_27.png
# Processed and saved: ../../data/preprocessed/15\crop_28.png
# Processed and saved: ../../data/preprocessed/15\crop_29.png
# Processed and saved: ../../data/preprocessed/15\crop_3.png
# Processed and saved: ../../data/preprocessed/15\crop_30.png
# Processed and saved: ../../data/preprocessed/15\crop_31.png
# Processed and saved: ../../data/preprocessed/15\crop_32.png
# Processed and saved: ../../data/preprocessed/15\crop_33.png
# Processed and saved: ../../data/preprocessed/15\crop_34.png
# Processed and saved: ../../data/preprocessed/15\crop_35.png
# Processed and saved: ../../data/preprocessed/15\crop_36.png
# Processed and saved: ../../data/preprocessed/15\crop_37.png
# Processed and saved: ../../data/preprocessed/15\crop_38.png
# Processed and saved: ../../data/preprocessed/15\crop_39.png
# Processed and saved: ../../data/preprocessed/15\crop_4.png
# Processed and saved: ../../data/preprocessed/15\crop_40.png
# Processed and saved: ../../data/preprocessed/15\crop_41.png
# Processed and saved: ../../data/preprocessed/15\crop_5.png
# Processed and saved: ../../data/preprocessed/15\crop_6.png
# Processed and saved: ../../data/preprocessed/15\crop_7.png
# Processed and saved: ../../data/preprocessed/15\crop_8.png
# Processed and saved: ../../data/preprocessed/15\crop_9.png
# Processed and saved: ../../data/preprocessed/16\crop_0.png
# Processed and saved: ../../data/preprocessed/16\crop_1.png
# Processed and saved: ../../data/preprocessed/16\crop_10.png
# Processed and saved: ../../data/preprocessed/16\crop_2.png
# Processed and saved: ../../data/preprocessed/16\crop_3.png
# Processed and saved: ../../data/preprocessed/16\crop_4.png
# Processed and saved: ../../data/preprocessed/16\crop_5.png
# Processed and saved: ../../data/preprocessed/16\crop_6.png
# Processed and saved: ../../data/preprocessed/16\crop_7.png
# Processed and saved: ../../data/preprocessed/16\crop_8.png
# Processed and saved: ../../data/preprocessed/16\crop_9.png
# Processed and saved: ../../data/preprocessed/17\crop_0.png
# Processed and saved: ../../data/preprocessed/17\crop_1.png
# Processed and saved: ../../data/preprocessed/17\crop_10.png
# Processed and saved: ../../data/preprocessed/17\crop_11.png
# Processed and saved: ../../data/preprocessed/17\crop_12.png
# Processed and saved: ../../data/preprocessed/17\crop_13.png
# Processed and saved: ../../data/preprocessed/17\crop_14.png
# Processed and saved: ../../data/preprocessed/17\crop_15.png
# Processed and saved: ../../data/preprocessed/17\crop_16.png
# Processed and saved: ../../data/preprocessed/17\crop_17.png
# Processed and saved: ../../data/preprocessed/17\crop_18.png
# Processed and saved: ../../data/preprocessed/17\crop_19.png
# Processed and saved: ../../data/preprocessed/17\crop_2.png
# Processed and saved: ../../data/preprocessed/17\crop_20.png
# Processed and saved: ../../data/preprocessed/17\crop_21.png
# Processed and saved: ../../data/preprocessed/17\crop_22.png
# Processed and saved: ../../data/preprocessed/17\crop_23.png
# Processed and saved: ../../data/preprocessed/17\crop_24.png
# Processed and saved: ../../data/preprocessed/17\crop_25.png
# Processed and saved: ../../data/preprocessed/17\crop_26.png
# Processed and saved: ../../data/preprocessed/17\crop_27.png
# Processed and saved: ../../data/preprocessed/17\crop_28.png
# Processed and saved: ../../data/preprocessed/17\crop_29.png
# Processed and saved: ../../data/preprocessed/17\crop_3.png
# Processed and saved: ../../data/preprocessed/17\crop_30.png
# Processed and saved: ../../data/preprocessed/17\crop_31.png
# Processed and saved: ../../data/preprocessed/17\crop_32.png
# Processed and saved: ../../data/preprocessed/17\crop_33.png
# Processed and saved: ../../data/preprocessed/17\crop_34.png
# Processed and saved: ../../data/preprocessed/17\crop_4.png
# Processed and saved: ../../data/preprocessed/17\crop_5.png
# Processed and saved: ../../data/preprocessed/17\crop_6.png
# Processed and saved: ../../data/preprocessed/17\crop_7.png
# Processed and saved: ../../data/preprocessed/17\crop_8.png
# Processed and saved: ../../data/preprocessed/17\crop_9.png
# Processed and saved: ../../data/preprocessed/18\crop_0.png
# Processed and saved: ../../data/preprocessed/18\crop_1.png
# Processed and saved: ../../data/preprocessed/18\crop_10.png
# Processed and saved: ../../data/preprocessed/18\crop_11.png
# Processed and saved: ../../data/preprocessed/18\crop_12.png
# Processed and saved: ../../data/preprocessed/18\crop_13.png
# Processed and saved: ../../data/preprocessed/18\crop_14.png
# Processed and saved: ../../data/preprocessed/18\crop_15.png
# Processed and saved: ../../data/preprocessed/18\crop_16.png
# Processed and saved: ../../data/preprocessed/18\crop_17.png
# Processed and saved: ../../data/preprocessed/18\crop_18.png
# Processed and saved: ../../data/preprocessed/18\crop_19.png
# Processed and saved: ../../data/preprocessed/18\crop_2.png
# Processed and saved: ../../data/preprocessed/18\crop_20.png
# Processed and saved: ../../data/preprocessed/18\crop_21.png
# Processed and saved: ../../data/preprocessed/18\crop_22.png
# Processed and saved: ../../data/preprocessed/18\crop_23.png
# Processed and saved: ../../data/preprocessed/18\crop_24.png
# Processed and saved: ../../data/preprocessed/18\crop_25.png
# Processed and saved: ../../data/preprocessed/18\crop_26.png
# Processed and saved: ../../data/preprocessed/18\crop_27.png
# Processed and saved: ../../data/preprocessed/18\crop_28.png
# Processed and saved: ../../data/preprocessed/18\crop_29.png
# Processed and saved: ../../data/preprocessed/18\crop_3.png
# Processed and saved: ../../data/preprocessed/18\crop_30.png
# Processed and saved: ../../data/preprocessed/18\crop_31.png
# Processed and saved: ../../data/preprocessed/18\crop_32.png
# Processed and saved: ../../data/preprocessed/18\crop_33.png
# Processed and saved: ../../data/preprocessed/18\crop_34.png
# Processed and saved: ../../data/preprocessed/18\crop_35.png
# Processed and saved: ../../data/preprocessed/18\crop_36.png
# Processed and saved: ../../data/preprocessed/18\crop_37.png
# Processed and saved: ../../data/preprocessed/18\crop_38.png
# Processed and saved: ../../data/preprocessed/18\crop_39.png
# Processed and saved: ../../data/preprocessed/18\crop_4.png
# Processed and saved: ../../data/preprocessed/18\crop_40.png
# Processed and saved: ../../data/preprocessed/18\crop_41.png
# Processed and saved: ../../data/preprocessed/18\crop_42.png
# Processed and saved: ../../data/preprocessed/18\crop_43.png
# Processed and saved: ../../data/preprocessed/18\crop_5.png
# Processed and saved: ../../data/preprocessed/18\crop_6.png
# Processed and saved: ../../data/preprocessed/18\crop_7.png
# Processed and saved: ../../data/preprocessed/18\crop_8.png
# Processed and saved: ../../data/preprocessed/18\crop_9.png
# Processed and saved: ../../data/preprocessed/19\crop_0.png
# Processed and saved: ../../data/preprocessed/19\crop_1.png
# Processed and saved: ../../data/preprocessed/19\crop_10.png
# Processed and saved: ../../data/preprocessed/19\crop_11.png
# Processed and saved: ../../data/preprocessed/19\crop_12.png
# Processed and saved: ../../data/preprocessed/19\crop_13.png
# Processed and saved: ../../data/preprocessed/19\crop_14.png
# Processed and saved: ../../data/preprocessed/19\crop_15.png
# Processed and saved: ../../data/preprocessed/19\crop_16.png
# Processed and saved: ../../data/preprocessed/19\crop_17.png
# Processed and saved: ../../data/preprocessed/19\crop_18.png
# Processed and saved: ../../data/preprocessed/19\crop_19.png
# Processed and saved: ../../data/preprocessed/19\crop_2.png
# Processed and saved: ../../data/preprocessed/19\crop_3.png
# Processed and saved: ../../data/preprocessed/19\crop_4.png
# Processed and saved: ../../data/preprocessed/19\crop_5.png
# Processed and saved: ../../data/preprocessed/19\crop_6.png
# Processed and saved: ../../data/preprocessed/19\crop_7.png
# Processed and saved: ../../data/preprocessed/19\crop_8.png
# Processed and saved: ../../data/preprocessed/19\crop_9.png
# Processed and saved: ../../data/preprocessed/2\crop_0.png
# Processed and saved: ../../data/preprocessed/2\crop_1.png
# Processed and saved: ../../data/preprocessed/2\crop_10.png
# Processed and saved: ../../data/preprocessed/2\crop_11.png
# Processed and saved: ../../data/preprocessed/2\crop_12.png
# Processed and saved: ../../data/preprocessed/2\crop_13.png
# Processed and saved: ../../data/preprocessed/2\crop_14.png
# Processed and saved: ../../data/preprocessed/2\crop_15.png
# Processed and saved: ../../data/preprocessed/2\crop_16.png
# Processed and saved: ../../data/preprocessed/2\crop_17.png
# Processed and saved: ../../data/preprocessed/2\crop_18.png
# Processed and saved: ../../data/preprocessed/2\crop_19.png
# Processed and saved: ../../data/preprocessed/2\crop_2.png
# Processed and saved: ../../data/preprocessed/2\crop_20.png
# Processed and saved: ../../data/preprocessed/2\crop_21.png
# Processed and saved: ../../data/preprocessed/2\crop_22.png
# Processed and saved: ../../data/preprocessed/2\crop_23.png
# Processed and saved: ../../data/preprocessed/2\crop_24.png
# Processed and saved: ../../data/preprocessed/2\crop_25.png
# Processed and saved: ../../data/preprocessed/2\crop_26.png
# Processed and saved: ../../data/preprocessed/2\crop_27.png
# Processed and saved: ../../data/preprocessed/2\crop_28.png
# Processed and saved: ../../data/preprocessed/2\crop_29.png
# Processed and saved: ../../data/preprocessed/2\crop_3.png
# Processed and saved: ../../data/preprocessed/2\crop_30.png
# Processed and saved: ../../data/preprocessed/2\crop_31.png
# Processed and saved: ../../data/preprocessed/2\crop_32.png
# Processed and saved: ../../data/preprocessed/2\crop_33.png
# Processed and saved: ../../data/preprocessed/2\crop_34.png
# Processed and saved: ../../data/preprocessed/2\crop_35.png
# Processed and saved: ../../data/preprocessed/2\crop_36.png
# Processed and saved: ../../data/preprocessed/2\crop_37.png
# Processed and saved: ../../data/preprocessed/2\crop_38.png
# Processed and saved: ../../data/preprocessed/2\crop_39.png
# Processed and saved: ../../data/preprocessed/2\crop_4.png
# Processed and saved: ../../data/preprocessed/2\crop_40.png
# Processed and saved: ../../data/preprocessed/2\crop_41.png
# Processed and saved: ../../data/preprocessed/2\crop_42.png
# Processed and saved: ../../data/preprocessed/2\crop_43.png
# Processed and saved: ../../data/preprocessed/2\crop_44.png
# Processed and saved: ../../data/preprocessed/2\crop_5.png
# Processed and saved: ../../data/preprocessed/2\crop_6.png
# Processed and saved: ../../data/preprocessed/2\crop_7.png
# Processed and saved: ../../data/preprocessed/2\crop_8.png
# Processed and saved: ../../data/preprocessed/2\crop_9.png
# Processed and saved: ../../data/preprocessed/20\crop_0.png
# Processed and saved: ../../data/preprocessed/20\crop_1.png
# Processed and saved: ../../data/preprocessed/20\crop_2.png
# Processed and saved: ../../data/preprocessed/20\crop_3.png
# Processed and saved: ../../data/preprocessed/21\crop_0.png
# Processed and saved: ../../data/preprocessed/21\crop_1.png
# Processed and saved: ../../data/preprocessed/21\crop_10.png
# Processed and saved: ../../data/preprocessed/21\crop_11.png
# Processed and saved: ../../data/preprocessed/21\crop_2.png
# Processed and saved: ../../data/preprocessed/21\crop_3.png
# Processed and saved: ../../data/preprocessed/21\crop_4.png
# Processed and saved: ../../data/preprocessed/21\crop_5.png
# Processed and saved: ../../data/preprocessed/21\crop_6.png
# Processed and saved: ../../data/preprocessed/21\crop_7.png
# Processed and saved: ../../data/preprocessed/21\crop_8.png
# Processed and saved: ../../data/preprocessed/21\crop_9.png
# Processed and saved: ../../data/preprocessed/22\crop_0.png
# Processed and saved: ../../data/preprocessed/22\crop_1.png
# Processed and saved: ../../data/preprocessed/22\crop_10.png
# Processed and saved: ../../data/preprocessed/22\crop_11.png
# Processed and saved: ../../data/preprocessed/22\crop_2.png
# Processed and saved: ../../data/preprocessed/22\crop_3.png
# Processed and saved: ../../data/preprocessed/22\crop_4.png
# Processed and saved: ../../data/preprocessed/22\crop_5.png
# Processed and saved: ../../data/preprocessed/22\crop_6.png
# Processed and saved: ../../data/preprocessed/22\crop_7.png
# Processed and saved: ../../data/preprocessed/22\crop_8.png
# Processed and saved: ../../data/preprocessed/22\crop_9.png
# Processed and saved: ../../data/preprocessed/23\crop_0.png
# Processed and saved: ../../data/preprocessed/23\crop_1.png
# Processed and saved: ../../data/preprocessed/23\crop_10.png
# Processed and saved: ../../data/preprocessed/23\crop_11.png
# Processed and saved: ../../data/preprocessed/23\crop_12.png
# Processed and saved: ../../data/preprocessed/23\crop_13.png
# Processed and saved: ../../data/preprocessed/23\crop_14.png
# Processed and saved: ../../data/preprocessed/23\crop_15.png
# Processed and saved: ../../data/preprocessed/23\crop_16.png
# Processed and saved: ../../data/preprocessed/23\crop_17.png
# Processed and saved: ../../data/preprocessed/23\crop_18.png
# Processed and saved: ../../data/preprocessed/23\crop_19.png
# Processed and saved: ../../data/preprocessed/23\crop_2.png
# Processed and saved: ../../data/preprocessed/23\crop_20.png
# Processed and saved: ../../data/preprocessed/23\crop_21.png
# Processed and saved: ../../data/preprocessed/23\crop_22.png
# Processed and saved: ../../data/preprocessed/23\crop_23.png
# Processed and saved: ../../data/preprocessed/23\crop_24.png
# Processed and saved: ../../data/preprocessed/23\crop_3.png
# Processed and saved: ../../data/preprocessed/23\crop_4.png
# Processed and saved: ../../data/preprocessed/23\crop_5.png
# Processed and saved: ../../data/preprocessed/23\crop_6.png
# Processed and saved: ../../data/preprocessed/23\crop_7.png
# Processed and saved: ../../data/preprocessed/23\crop_8.png
# Processed and saved: ../../data/preprocessed/23\crop_9.png
# Processed and saved: ../../data/preprocessed/24\crop_0.png
# Processed and saved: ../../data/preprocessed/24\crop_1.png
# Processed and saved: ../../data/preprocessed/24\crop_10.png
# Processed and saved: ../../data/preprocessed/24\crop_11.png
# Processed and saved: ../../data/preprocessed/24\crop_12.png
# Processed and saved: ../../data/preprocessed/24\crop_13.png
# Processed and saved: ../../data/preprocessed/24\crop_14.png
# Processed and saved: ../../data/preprocessed/24\crop_15.png
# Processed and saved: ../../data/preprocessed/24\crop_16.png
# Processed and saved: ../../data/preprocessed/24\crop_17.png
# Processed and saved: ../../data/preprocessed/24\crop_18.png
# Processed and saved: ../../data/preprocessed/24\crop_19.png
# Processed and saved: ../../data/preprocessed/24\crop_2.png
# Processed and saved: ../../data/preprocessed/24\crop_20.png
# Processed and saved: ../../data/preprocessed/24\crop_21.png
# Processed and saved: ../../data/preprocessed/24\crop_3.png
# Processed and saved: ../../data/preprocessed/24\crop_4.png
# Processed and saved: ../../data/preprocessed/24\crop_5.png
# Processed and saved: ../../data/preprocessed/24\crop_6.png
# Processed and saved: ../../data/preprocessed/24\crop_7.png
# Processed and saved: ../../data/preprocessed/24\crop_8.png
# Processed and saved: ../../data/preprocessed/24\crop_9.png
# Processed and saved: ../../data/preprocessed/25\crop_0.png
# Processed and saved: ../../data/preprocessed/25\crop_1.png
# Processed and saved: ../../data/preprocessed/25\crop_10.png
# Processed and saved: ../../data/preprocessed/25\crop_11.png
# Processed and saved: ../../data/preprocessed/25\crop_12.png
# Processed and saved: ../../data/preprocessed/25\crop_13.png
# Processed and saved: ../../data/preprocessed/25\crop_14.png
# Processed and saved: ../../data/preprocessed/25\crop_15.png
# Processed and saved: ../../data/preprocessed/25\crop_16.png
# Processed and saved: ../../data/preprocessed/25\crop_17.png
# Processed and saved: ../../data/preprocessed/25\crop_18.png
# Processed and saved: ../../data/preprocessed/25\crop_19.png
# Processed and saved: ../../data/preprocessed/25\crop_2.png
# Processed and saved: ../../data/preprocessed/25\crop_20.png
# Processed and saved: ../../data/preprocessed/25\crop_21.png
# Processed and saved: ../../data/preprocessed/25\crop_3.png
# Processed and saved: ../../data/preprocessed/25\crop_4.png
# Processed and saved: ../../data/preprocessed/25\crop_5.png
# Processed and saved: ../../data/preprocessed/25\crop_6.png
# Processed and saved: ../../data/preprocessed/25\crop_7.png
# Processed and saved: ../../data/preprocessed/25\crop_8.png
# Processed and saved: ../../data/preprocessed/25\crop_9.png
# Processed and saved: ../../data/preprocessed/26\crop_0.png
# Processed and saved: ../../data/preprocessed/26\crop_1.png
# Processed and saved: ../../data/preprocessed/26\crop_10.png
# Processed and saved: ../../data/preprocessed/26\crop_11.png
# Processed and saved: ../../data/preprocessed/26\crop_12.png
# Processed and saved: ../../data/preprocessed/26\crop_13.png
# Processed and saved: ../../data/preprocessed/26\crop_14.png
# Processed and saved: ../../data/preprocessed/26\crop_15.png
# Processed and saved: ../../data/preprocessed/26\crop_16.png
# Processed and saved: ../../data/preprocessed/26\crop_2.png
# Processed and saved: ../../data/preprocessed/26\crop_3.png
# Processed and saved: ../../data/preprocessed/26\crop_4.png
# Processed and saved: ../../data/preprocessed/26\crop_5.png
# Processed and saved: ../../data/preprocessed/26\crop_6.png
# Processed and saved: ../../data/preprocessed/26\crop_7.png
# Processed and saved: ../../data/preprocessed/26\crop_8.png
# Processed and saved: ../../data/preprocessed/26\crop_9.png
# Processed and saved: ../../data/preprocessed/27\crop_0.png
# Processed and saved: ../../data/preprocessed/28\crop_0.png
# Processed and saved: ../../data/preprocessed/28\crop_1.png
# Processed and saved: ../../data/preprocessed/28\crop_2.png
# Processed and saved: ../../data/preprocessed/28\crop_3.png
# Processed and saved: ../../data/preprocessed/28\crop_4.png
# Processed and saved: ../../data/preprocessed/28\crop_5.png
# Processed and saved: ../../data/preprocessed/28\crop_6.png
# Processed and saved: ../../data/preprocessed/28\crop_7.png
# Processed and saved: ../../data/preprocessed/28\crop_8.png
# Processed and saved: ../../data/preprocessed/29\crop_0.png
# Processed and saved: ../../data/preprocessed/29\crop_1.png
# Processed and saved: ../../data/preprocessed/29\crop_10.png
# Processed and saved: ../../data/preprocessed/29\crop_11.png
# Processed and saved: ../../data/preprocessed/29\crop_12.png
# Processed and saved: ../../data/preprocessed/29\crop_13.png
# Processed and saved: ../../data/preprocessed/29\crop_14.png
# Processed and saved: ../../data/preprocessed/29\crop_15.png
# Processed and saved: ../../data/preprocessed/29\crop_2.png
# Processed and saved: ../../data/preprocessed/29\crop_3.png
# Processed and saved: ../../data/preprocessed/29\crop_4.png
# Processed and saved: ../../data/preprocessed/29\crop_5.png
# Processed and saved: ../../data/preprocessed/29\crop_6.png
# Processed and saved: ../../data/preprocessed/29\crop_7.png
# Processed and saved: ../../data/preprocessed/29\crop_8.png
# Processed and saved: ../../data/preprocessed/29\crop_9.png
# Processed and saved: ../../data/preprocessed/3\crop_0.png
# Processed and saved: ../../data/preprocessed/3\crop_1.png
# Processed and saved: ../../data/preprocessed/3\crop_10.png
# Processed and saved: ../../data/preprocessed/3\crop_11.png
# Processed and saved: ../../data/preprocessed/3\crop_12.png
# Processed and saved: ../../data/preprocessed/3\crop_13.png
# Processed and saved: ../../data/preprocessed/3\crop_14.png
# Processed and saved: ../../data/preprocessed/3\crop_15.png
# Processed and saved: ../../data/preprocessed/3\crop_16.png
# Processed and saved: ../../data/preprocessed/3\crop_17.png
# Processed and saved: ../../data/preprocessed/3\crop_18.png
# Processed and saved: ../../data/preprocessed/3\crop_19.png
# Processed and saved: ../../data/preprocessed/3\crop_2.png
# Processed and saved: ../../data/preprocessed/3\crop_20.png
# Processed and saved: ../../data/preprocessed/3\crop_21.png
# Processed and saved: ../../data/preprocessed/3\crop_22.png
# Processed and saved: ../../data/preprocessed/3\crop_23.png
# Processed and saved: ../../data/preprocessed/3\crop_24.png
# Processed and saved: ../../data/preprocessed/3\crop_25.png
# Processed and saved: ../../data/preprocessed/3\crop_26.png
# Processed and saved: ../../data/preprocessed/3\crop_27.png
# Processed and saved: ../../data/preprocessed/3\crop_28.png
# Processed and saved: ../../data/preprocessed/3\crop_29.png
# Processed and saved: ../../data/preprocessed/3\crop_3.png
# Processed and saved: ../../data/preprocessed/3\crop_30.png
# Processed and saved: ../../data/preprocessed/3\crop_31.png
# Processed and saved: ../../data/preprocessed/3\crop_32.png
# Processed and saved: ../../data/preprocessed/3\crop_33.png
# Processed and saved: ../../data/preprocessed/3\crop_34.png
# Processed and saved: ../../data/preprocessed/3\crop_35.png
# Processed and saved: ../../data/preprocessed/3\crop_36.png
# Processed and saved: ../../data/preprocessed/3\crop_4.png
# Processed and saved: ../../data/preprocessed/3\crop_5.png
# Processed and saved: ../../data/preprocessed/3\crop_6.png
# Processed and saved: ../../data/preprocessed/3\crop_7.png
# Processed and saved: ../../data/preprocessed/3\crop_8.png
# Processed and saved: ../../data/preprocessed/3\crop_9.png
# Processed and saved: ../../data/preprocessed/30\crop_0.png
# Processed and saved: ../../data/preprocessed/30\crop_1.png
# Processed and saved: ../../data/preprocessed/30\crop_10.png
# Processed and saved: ../../data/preprocessed/30\crop_11.png
# Processed and saved: ../../data/preprocessed/30\crop_12.png
# Processed and saved: ../../data/preprocessed/30\crop_13.png
# Processed and saved: ../../data/preprocessed/30\crop_14.png
# Processed and saved: ../../data/preprocessed/30\crop_15.png
# Processed and saved: ../../data/preprocessed/30\crop_16.png
# Processed and saved: ../../data/preprocessed/30\crop_17.png
# Processed and saved: ../../data/preprocessed/30\crop_18.png
# Processed and saved: ../../data/preprocessed/30\crop_19.png
# Processed and saved: ../../data/preprocessed/30\crop_2.png
# Processed and saved: ../../data/preprocessed/30\crop_20.png
# Processed and saved: ../../data/preprocessed/30\crop_21.png
# Processed and saved: ../../data/preprocessed/30\crop_22.png
# Processed and saved: ../../data/preprocessed/30\crop_23.png
# Processed and saved: ../../data/preprocessed/30\crop_24.png
# Processed and saved: ../../data/preprocessed/30\crop_25.png
# Processed and saved: ../../data/preprocessed/30\crop_26.png
# Processed and saved: ../../data/preprocessed/30\crop_27.png
# Processed and saved: ../../data/preprocessed/30\crop_28.png
# Processed and saved: ../../data/preprocessed/30\crop_29.png
# Processed and saved: ../../data/preprocessed/30\crop_3.png
# Processed and saved: ../../data/preprocessed/30\crop_30.png
# Processed and saved: ../../data/preprocessed/30\crop_31.png
# Processed and saved: ../../data/preprocessed/30\crop_32.png
# Processed and saved: ../../data/preprocessed/30\crop_33.png
# Processed and saved: ../../data/preprocessed/30\crop_34.png
# Processed and saved: ../../data/preprocessed/30\crop_35.png
# Processed and saved: ../../data/preprocessed/30\crop_36.png
# Processed and saved: ../../data/preprocessed/30\crop_37.png
# Processed and saved: ../../data/preprocessed/30\crop_38.png
# Processed and saved: ../../data/preprocessed/30\crop_39.png
# Processed and saved: ../../data/preprocessed/30\crop_4.png
# Processed and saved: ../../data/preprocessed/30\crop_40.png
# Processed and saved: ../../data/preprocessed/30\crop_41.png
# Processed and saved: ../../data/preprocessed/30\crop_42.png
# Processed and saved: ../../data/preprocessed/30\crop_43.png
# Processed and saved: ../../data/preprocessed/30\crop_44.png
# Processed and saved: ../../data/preprocessed/30\crop_45.png
# Processed and saved: ../../data/preprocessed/30\crop_46.png
# Processed and saved: ../../data/preprocessed/30\crop_47.png
# Processed and saved: ../../data/preprocessed/30\crop_48.png
# Processed and saved: ../../data/preprocessed/30\crop_49.png
# Processed and saved: ../../data/preprocessed/30\crop_5.png
# Processed and saved: ../../data/preprocessed/30\crop_50.png
# Processed and saved: ../../data/preprocessed/30\crop_51.png
# Processed and saved: ../../data/preprocessed/30\crop_52.png
# Processed and saved: ../../data/preprocessed/30\crop_53.png
# Processed and saved: ../../data/preprocessed/30\crop_54.png
# Processed and saved: ../../data/preprocessed/30\crop_55.png
# Processed and saved: ../../data/preprocessed/30\crop_56.png
# Processed and saved: ../../data/preprocessed/30\crop_57.png
# Processed and saved: ../../data/preprocessed/30\crop_58.png
# Processed and saved: ../../data/preprocessed/30\crop_6.png
# Processed and saved: ../../data/preprocessed/30\crop_7.png
# Processed and saved: ../../data/preprocessed/30\crop_8.png
# Processed and saved: ../../data/preprocessed/30\crop_9.png
# Processed and saved: ../../data/preprocessed/31\crop_0.png
# Processed and saved: ../../data/preprocessed/31\crop_1.png
# Processed and saved: ../../data/preprocessed/31\crop_10.png
# Processed and saved: ../../data/preprocessed/31\crop_11.png
# Processed and saved: ../../data/preprocessed/31\crop_12.png
# Processed and saved: ../../data/preprocessed/31\crop_13.png
# Processed and saved: ../../data/preprocessed/31\crop_14.png
# Processed and saved: ../../data/preprocessed/31\crop_15.png
# Processed and saved: ../../data/preprocessed/31\crop_16.png
# Processed and saved: ../../data/preprocessed/31\crop_17.png
# Processed and saved: ../../data/preprocessed/31\crop_18.png
# Processed and saved: ../../data/preprocessed/31\crop_19.png
# Processed and saved: ../../data/preprocessed/31\crop_2.png
# Processed and saved: ../../data/preprocessed/31\crop_20.png
# Processed and saved: ../../data/preprocessed/31\crop_21.png
# Processed and saved: ../../data/preprocessed/31\crop_22.png
# Processed and saved: ../../data/preprocessed/31\crop_23.png
# Processed and saved: ../../data/preprocessed/31\crop_24.png
# Processed and saved: ../../data/preprocessed/31\crop_25.png
# Processed and saved: ../../data/preprocessed/31\crop_26.png
# Processed and saved: ../../data/preprocessed/31\crop_27.png
# Processed and saved: ../../data/preprocessed/31\crop_28.png
# Processed and saved: ../../data/preprocessed/31\crop_29.png
# Processed and saved: ../../data/preprocessed/31\crop_3.png
# Processed and saved: ../../data/preprocessed/31\crop_30.png
# Processed and saved: ../../data/preprocessed/31\crop_31.png
# Processed and saved: ../../data/preprocessed/31\crop_32.png
# Processed and saved: ../../data/preprocessed/31\crop_33.png
# Processed and saved: ../../data/preprocessed/31\crop_34.png
# Processed and saved: ../../data/preprocessed/31\crop_35.png
# Processed and saved: ../../data/preprocessed/31\crop_36.png
# Processed and saved: ../../data/preprocessed/31\crop_37.png
# Processed and saved: ../../data/preprocessed/31\crop_38.png
# Processed and saved: ../../data/preprocessed/31\crop_39.png
# Processed and saved: ../../data/preprocessed/31\crop_4.png
# Processed and saved: ../../data/preprocessed/31\crop_40.png
# Processed and saved: ../../data/preprocessed/31\crop_41.png
# Processed and saved: ../../data/preprocessed/31\crop_42.png
# Processed and saved: ../../data/preprocessed/31\crop_43.png
# Processed and saved: ../../data/preprocessed/31\crop_44.png
# Processed and saved: ../../data/preprocessed/31\crop_45.png
# Processed and saved: ../../data/preprocessed/31\crop_46.png
# Processed and saved: ../../data/preprocessed/31\crop_47.png
# Processed and saved: ../../data/preprocessed/31\crop_48.png
# Processed and saved: ../../data/preprocessed/31\crop_49.png
# Processed and saved: ../../data/preprocessed/31\crop_5.png
# Processed and saved: ../../data/preprocessed/31\crop_50.png
# Processed and saved: ../../data/preprocessed/31\crop_51.png
# Processed and saved: ../../data/preprocessed/31\crop_52.png
# Processed and saved: ../../data/preprocessed/31\crop_53.png
# Processed and saved: ../../data/preprocessed/31\crop_54.png
# Processed and saved: ../../data/preprocessed/31\crop_55.png
# Processed and saved: ../../data/preprocessed/31\crop_56.png
# Processed and saved: ../../data/preprocessed/31\crop_57.png
# Processed and saved: ../../data/preprocessed/31\crop_58.png
# Processed and saved: ../../data/preprocessed/31\crop_59.png
# Processed and saved: ../../data/preprocessed/31\crop_6.png
# Processed and saved: ../../data/preprocessed/31\crop_60.png
# Processed and saved: ../../data/preprocessed/31\crop_61.png
# Processed and saved: ../../data/preprocessed/31\crop_62.png
# Processed and saved: ../../data/preprocessed/31\crop_7.png
# Processed and saved: ../../data/preprocessed/31\crop_8.png
# Processed and saved: ../../data/preprocessed/31\crop_9.png
# Processed and saved: ../../data/preprocessed/32\crop_0.png
# Processed and saved: ../../data/preprocessed/32\crop_1.png
# Processed and saved: ../../data/preprocessed/32\crop_10.png
# Processed and saved: ../../data/preprocessed/32\crop_11.png
# Processed and saved: ../../data/preprocessed/32\crop_12.png
# Processed and saved: ../../data/preprocessed/32\crop_13.png
# Processed and saved: ../../data/preprocessed/32\crop_14.png
# Processed and saved: ../../data/preprocessed/32\crop_15.png
# Processed and saved: ../../data/preprocessed/32\crop_16.png
# Processed and saved: ../../data/preprocessed/32\crop_17.png
# Processed and saved: ../../data/preprocessed/32\crop_18.png
# Processed and saved: ../../data/preprocessed/32\crop_19.png
# Processed and saved: ../../data/preprocessed/32\crop_2.png
# Processed and saved: ../../data/preprocessed/32\crop_20.png
# Processed and saved: ../../data/preprocessed/32\crop_21.png
# Processed and saved: ../../data/preprocessed/32\crop_22.png
# Processed and saved: ../../data/preprocessed/32\crop_23.png
# Processed and saved: ../../data/preprocessed/32\crop_24.png
# Processed and saved: ../../data/preprocessed/32\crop_25.png
# Processed and saved: ../../data/preprocessed/32\crop_26.png
# Processed and saved: ../../data/preprocessed/32\crop_27.png
# Processed and saved: ../../data/preprocessed/32\crop_28.png
# Processed and saved: ../../data/preprocessed/32\crop_29.png
# Processed and saved: ../../data/preprocessed/32\crop_3.png
# Processed and saved: ../../data/preprocessed/32\crop_30.png
# Processed and saved: ../../data/preprocessed/32\crop_31.png
# Processed and saved: ../../data/preprocessed/32\crop_32.png
# Processed and saved: ../../data/preprocessed/32\crop_33.png
# Processed and saved: ../../data/preprocessed/32\crop_34.png
# Processed and saved: ../../data/preprocessed/32\crop_35.png
# Processed and saved: ../../data/preprocessed/32\crop_36.png
# Processed and saved: ../../data/preprocessed/32\crop_37.png
# Processed and saved: ../../data/preprocessed/32\crop_4.png
# Processed and saved: ../../data/preprocessed/32\crop_5.png
# Processed and saved: ../../data/preprocessed/32\crop_6.png
# Processed and saved: ../../data/preprocessed/32\crop_7.png
# Processed and saved: ../../data/preprocessed/32\crop_8.png
# Processed and saved: ../../data/preprocessed/32\crop_9.png
# Processed and saved: ../../data/preprocessed/33\crop_0.png
# Processed and saved: ../../data/preprocessed/33\crop_1.png
# Processed and saved: ../../data/preprocessed/33\crop_10.png
# Processed and saved: ../../data/preprocessed/33\crop_11.png
# Processed and saved: ../../data/preprocessed/33\crop_12.png
# Processed and saved: ../../data/preprocessed/33\crop_13.png
# Processed and saved: ../../data/preprocessed/33\crop_14.png
# Processed and saved: ../../data/preprocessed/33\crop_15.png
# Processed and saved: ../../data/preprocessed/33\crop_16.png
# ...
# Processed and saved: ../../data/preprocessed/82\crop_7.png
# Processed and saved: ../../data/preprocessed/82\crop_8.png
# Processed and saved: ../../data/preprocessed/82\crop_9.png
# Processed and saved: ../../data/preprocessed/83\crop_0.png
# Processed and saved: ../../data/preprocessed/83\crop_1.png
# Processed and saved: ../../data/preprocessed/83\crop_2.png
# Processed and saved: ../../data/preprocessed/83\crop_3.png
# Processed and saved: ../../data/preprocessed/84\crop_0.png
# Processed and saved: ../../data/preprocessed/84\crop_1.png
# Processed and saved: ../../data/preprocessed/84\crop_10.png
# Processed and saved: ../../data/preprocessed/84\crop_11.png
# Processed and saved: ../../data/preprocessed/84\crop_12.png
# Processed and saved: ../../data/preprocessed/84\crop_13.png
# Processed and saved: ../../data/preprocessed/84\crop_14.png
# Processed and saved: ../../data/preprocessed/84\crop_15.png
# Processed and saved: ../../data/preprocessed/84\crop_16.png
# Processed and saved: ../../data/preprocessed/84\crop_17.png
# Processed and saved: ../../data/preprocessed/84\crop_18.png
# Processed and saved: ../../data/preprocessed/84\crop_19.png
# Processed and saved: ../../data/preprocessed/84\crop_2.png
# Processed and saved: ../../data/preprocessed/84\crop_20.png
# Processed and saved: ../../data/preprocessed/84\crop_21.png
# Processed and saved: ../../data/preprocessed/84\crop_22.png
# Processed and saved: ../../data/preprocessed/84\crop_23.png
# Processed and saved: ../../data/preprocessed/84\crop_24.png
# Processed and saved: ../../data/preprocessed/84\crop_25.png
# Processed and saved: ../../data/preprocessed/84\crop_26.png
# Processed and saved: ../../data/preprocessed/84\crop_27.png
# Processed and saved: ../../data/preprocessed/84\crop_28.png
# Processed and saved: ../../data/preprocessed/84\crop_29.png
# Processed and saved: ../../data/preprocessed/84\crop_3.png
# Processed and saved: ../../data/preprocessed/84\crop_30.png
# Processed and saved: ../../data/preprocessed/84\crop_31.png
# Processed and saved: ../../data/preprocessed/84\crop_32.png
# Processed and saved: ../../data/preprocessed/84\crop_33.png
# Processed and saved: ../../data/preprocessed/84\crop_34.png
# Processed and saved: ../../data/preprocessed/84\crop_4.png
# Processed and saved: ../../data/preprocessed/84\crop_5.png
# Processed and saved: ../../data/preprocessed/84\crop_6.png
# Processed and saved: ../../data/preprocessed/84\crop_7.png
# Processed and saved: ../../data/preprocessed/84\crop_8.png
# Processed and saved: ../../data/preprocessed/84\crop_9.png
# Processed and saved: ../../data/preprocessed/85\crop_0.png
# Processed and saved: ../../data/preprocessed/85\crop_1.png
# Processed and saved: ../../data/preprocessed/85\crop_10.png
# Processed and saved: ../../data/preprocessed/85\crop_11.png
# Processed and saved: ../../data/preprocessed/85\crop_12.png
# Processed and saved: ../../data/preprocessed/85\crop_13.png
# Processed and saved: ../../data/preprocessed/85\crop_14.png
# Processed and saved: ../../data/preprocessed/85\crop_15.png
# Processed and saved: ../../data/preprocessed/85\crop_16.png
# Processed and saved: ../../data/preprocessed/85\crop_2.png
# Processed and saved: ../../data/preprocessed/85\crop_3.png
# Processed and saved: ../../data/preprocessed/85\crop_4.png
# Processed and saved: ../../data/preprocessed/85\crop_5.png
# Processed and saved: ../../data/preprocessed/85\crop_6.png
# Processed and saved: ../../data/preprocessed/85\crop_7.png
# Processed and saved: ../../data/preprocessed/85\crop_8.png
# Processed and saved: ../../data/preprocessed/85\crop_9.png
# Processed and saved: ../../data/preprocessed/86\crop_0.png
# Processed and saved: ../../data/preprocessed/86\crop_1.png
# Processed and saved: ../../data/preprocessed/86\crop_10.png
# Processed and saved: ../../data/preprocessed/86\crop_11.png
# Processed and saved: ../../data/preprocessed/86\crop_12.png
# Processed and saved: ../../data/preprocessed/86\crop_13.png
# Processed and saved: ../../data/preprocessed/86\crop_14.png
# Processed and saved: ../../data/preprocessed/86\crop_15.png
# Processed and saved: ../../data/preprocessed/86\crop_16.png
# Processed and saved: ../../data/preprocessed/86\crop_17.png
# Processed and saved: ../../data/preprocessed/86\crop_18.png
# Processed and saved: ../../data/preprocessed/86\crop_19.png
# Processed and saved: ../../data/preprocessed/86\crop_2.png
# Processed and saved: ../../data/preprocessed/86\crop_20.png
# Processed and saved: ../../data/preprocessed/86\crop_21.png
# Processed and saved: ../../data/preprocessed/86\crop_22.png
# Processed and saved: ../../data/preprocessed/86\crop_3.png
# Processed and saved: ../../data/preprocessed/86\crop_4.png
# Processed and saved: ../../data/preprocessed/86\crop_5.png
# Processed and saved: ../../data/preprocessed/86\crop_6.png
# Processed and saved: ../../data/preprocessed/86\crop_7.png
# Processed and saved: ../../data/preprocessed/86\crop_8.png
# Processed and saved: ../../data/preprocessed/86\crop_9.png
# Processed and saved: ../../data/preprocessed/87\crop_0.png
# Processed and saved: ../../data/preprocessed/87\crop_1.png
# Processed and saved: ../../data/preprocessed/87\crop_10.png
# Processed and saved: ../../data/preprocessed/87\crop_11.png
# Processed and saved: ../../data/preprocessed/87\crop_12.png
# Processed and saved: ../../data/preprocessed/87\crop_2.png
# Processed and saved: ../../data/preprocessed/87\crop_3.png
# Processed and saved: ../../data/preprocessed/87\crop_4.png
# Processed and saved: ../../data/preprocessed/87\crop_5.png
# Processed and saved: ../../data/preprocessed/87\crop_6.png
# Processed and saved: ../../data/preprocessed/87\crop_7.png
# Processed and saved: ../../data/preprocessed/87\crop_8.png
# Processed and saved: ../../data/preprocessed/87\crop_9.png
# Processed and saved: ../../data/preprocessed/88\crop_0.png
# Processed and saved: ../../data/preprocessed/88\crop_1.png
# Processed and saved: ../../data/preprocessed/88\crop_2.png
# Processed and saved: ../../data/preprocessed/89\crop_0.png
# Processed and saved: ../../data/preprocessed/89\crop_1.png
# Processed and saved: ../../data/preprocessed/89\crop_10.png
# Processed and saved: ../../data/preprocessed/89\crop_11.png
# Processed and saved: ../../data/preprocessed/89\crop_12.png
# Processed and saved: ../../data/preprocessed/89\crop_13.png
# Processed and saved: ../../data/preprocessed/89\crop_14.png
# Processed and saved: ../../data/preprocessed/89\crop_15.png
# Processed and saved: ../../data/preprocessed/89\crop_16.png
# Processed and saved: ../../data/preprocessed/89\crop_17.png
# Processed and saved: ../../data/preprocessed/89\crop_18.png
# Processed and saved: ../../data/preprocessed/89\crop_19.png
# Processed and saved: ../../data/preprocessed/89\crop_2.png
# Processed and saved: ../../data/preprocessed/89\crop_3.png
# Processed and saved: ../../data/preprocessed/89\crop_4.png
# Processed and saved: ../../data/preprocessed/89\crop_5.png
# Processed and saved: ../../data/preprocessed/89\crop_6.png
# Processed and saved: ../../data/preprocessed/89\crop_7.png
# Processed and saved: ../../data/preprocessed/89\crop_8.png
# Processed and saved: ../../data/preprocessed/89\crop_9.png
# Processed and saved: ../../data/preprocessed/9\crop_0.png
# Processed and saved: ../../data/preprocessed/9\crop_1.png
# Processed and saved: ../../data/preprocessed/9\crop_10.png
# Processed and saved: ../../data/preprocessed/9\crop_11.png
# Processed and saved: ../../data/preprocessed/9\crop_12.png
# Processed and saved: ../../data/preprocessed/9\crop_13.png
# Processed and saved: ../../data/preprocessed/9\crop_14.png
# Processed and saved: ../../data/preprocessed/9\crop_15.png
# Processed and saved: ../../data/preprocessed/9\crop_16.png
# Processed and saved: ../../data/preprocessed/9\crop_17.png
# Processed and saved: ../../data/preprocessed/9\crop_18.png
# Processed and saved: ../../data/preprocessed/9\crop_19.png
# Processed and saved: ../../data/preprocessed/9\crop_2.png
# Processed and saved: ../../data/preprocessed/9\crop_20.png
# Processed and saved: ../../data/preprocessed/9\crop_21.png
# Processed and saved: ../../data/preprocessed/9\crop_22.png
# Processed and saved: ../../data/preprocessed/9\crop_3.png
# Processed and saved: ../../data/preprocessed/9\crop_4.png
# Processed and saved: ../../data/preprocessed/9\crop_5.png
# Processed and saved: ../../data/preprocessed/9\crop_6.png
# Processed and saved: ../../data/preprocessed/9\crop_7.png
# Processed and saved: ../../data/preprocessed/9\crop_8.png
# Processed and saved: ../../data/preprocessed/9\crop_9.png
# Processed and saved: ../../data/preprocessed/90\crop_0.png
# Processed and saved: ../../data/preprocessed/90\crop_1.png
# Processed and saved: ../../data/preprocessed/90\crop_10.png
# Processed and saved: ../../data/preprocessed/90\crop_11.png
# Processed and saved: ../../data/preprocessed/90\crop_12.png
# Processed and saved: ../../data/preprocessed/90\crop_13.png
# Processed and saved: ../../data/preprocessed/90\crop_14.png
# Processed and saved: ../../data/preprocessed/90\crop_15.png
# Processed and saved: ../../data/preprocessed/90\crop_16.png
# Processed and saved: ../../data/preprocessed/90\crop_17.png
# Processed and saved: ../../data/preprocessed/90\crop_18.png
# Processed and saved: ../../data/preprocessed/90\crop_19.png
# Processed and saved: ../../data/preprocessed/90\crop_2.png
# Processed and saved: ../../data/preprocessed/90\crop_20.png
# Processed and saved: ../../data/preprocessed/90\crop_21.png
# Processed and saved: ../../data/preprocessed/90\crop_22.png
# Processed and saved: ../../data/preprocessed/90\crop_23.png
# Processed and saved: ../../data/preprocessed/90\crop_24.png
# Processed and saved: ../../data/preprocessed/90\crop_25.png
# Processed and saved: ../../data/preprocessed/90\crop_26.png
# Processed and saved: ../../data/preprocessed/90\crop_27.png
# Processed and saved: ../../data/preprocessed/90\crop_28.png
# Processed and saved: ../../data/preprocessed/90\crop_29.png
# Processed and saved: ../../data/preprocessed/90\crop_3.png
# Processed and saved: ../../data/preprocessed/90\crop_30.png
# Processed and saved: ../../data/preprocessed/90\crop_31.png
# Processed and saved: ../../data/preprocessed/90\crop_32.png
# Processed and saved: ../../data/preprocessed/90\crop_33.png
# Processed and saved: ../../data/preprocessed/90\crop_34.png
# Processed and saved: ../../data/preprocessed/90\crop_35.png
# Processed and saved: ../../data/preprocessed/90\crop_36.png
# Processed and saved: ../../data/preprocessed/90\crop_37.png
# Processed and saved: ../../data/preprocessed/90\crop_38.png
# Processed and saved: ../../data/preprocessed/90\crop_4.png
# Processed and saved: ../../data/preprocessed/90\crop_5.png
# Processed and saved: ../../data/preprocessed/90\crop_6.png
# Processed and saved: ../../data/preprocessed/90\crop_7.png
# Processed and saved: ../../data/preprocessed/90\crop_8.png
# Processed and saved: ../../data/preprocessed/90\crop_9.png
# Processed and saved: ../../data/preprocessed/91\crop_0.png
# Processed and saved: ../../data/preprocessed/91\crop_1.png
# Processed and saved: ../../data/preprocessed/91\crop_2.png
# Processed and saved: ../../data/preprocessed/92\crop_0.png
# Processed and saved: ../../data/preprocessed/92\crop_1.png
# Processed and saved: ../../data/preprocessed/92\crop_10.png
# Processed and saved: ../../data/preprocessed/92\crop_11.png
# Processed and saved: ../../data/preprocessed/92\crop_12.png
# Processed and saved: ../../data/preprocessed/92\crop_13.png
# Processed and saved: ../../data/preprocessed/92\crop_14.png
# Processed and saved: ../../data/preprocessed/92\crop_15.png
# Processed and saved: ../../data/preprocessed/92\crop_16.png
# Processed and saved: ../../data/preprocessed/92\crop_17.png
# Processed and saved: ../../data/preprocessed/92\crop_18.png
# Processed and saved: ../../data/preprocessed/92\crop_19.png
# Processed and saved: ../../data/preprocessed/92\crop_2.png
# Processed and saved: ../../data/preprocessed/92\crop_20.png
# Processed and saved: ../../data/preprocessed/92\crop_21.png
# Processed and saved: ../../data/preprocessed/92\crop_22.png
# Processed and saved: ../../data/preprocessed/92\crop_23.png
# Processed and saved: ../../data/preprocessed/92\crop_24.png
# Processed and saved: ../../data/preprocessed/92\crop_25.png
# Processed and saved: ../../data/preprocessed/92\crop_26.png
# Processed and saved: ../../data/preprocessed/92\crop_3.png
# Processed and saved: ../../data/preprocessed/92\crop_4.png
# Processed and saved: ../../data/preprocessed/92\crop_5.png
# Processed and saved: ../../data/preprocessed/92\crop_6.png
# Processed and saved: ../../data/preprocessed/92\crop_7.png
# Processed and saved: ../../data/preprocessed/92\crop_8.png
# Processed and saved: ../../data/preprocessed/92\crop_9.png
# Processed and saved: ../../data/preprocessed/93\crop_0.png
# Processed and saved: ../../data/preprocessed/93\crop_1.png
# Processed and saved: ../../data/preprocessed/93\crop_2.png
# Processed and saved: ../../data/preprocessed/93\crop_3.png
# Processed and saved: ../../data/preprocessed/93\crop_4.png
# Processed and saved: ../../data/preprocessed/93\crop_5.png
# Processed and saved: ../../data/preprocessed/93\crop_6.png
# Processed and saved: ../../data/preprocessed/93\crop_7.png
# Processed and saved: ../../data/preprocessed/93\crop_8.png
# Processed and saved: ../../data/preprocessed/94\crop_0.png
# Processed and saved: ../../data/preprocessed/94\crop_1.png
# Processed and saved: ../../data/preprocessed/94\crop_2.png
# Processed and saved: ../../data/preprocessed/94\crop_3.png
# Processed and saved: ../../data/preprocessed/96\crop_0.png
# Processed and saved: ../../data/preprocessed/96\crop_1.png
# Processed and saved: ../../data/preprocessed/96\crop_10.png
# Processed and saved: ../../data/preprocessed/96\crop_2.png
# Processed and saved: ../../data/preprocessed/96\crop_3.png
# Processed and saved: ../../data/preprocessed/96\crop_4.png
# Processed and saved: ../../data/preprocessed/96\crop_5.png
# Processed and saved: ../../data/preprocessed/96\crop_6.png
# Processed and saved: ../../data/preprocessed/96\crop_7.png
# Processed and saved: ../../data/preprocessed/96\crop_8.png
# Processed and saved: ../../data/preprocessed/96\crop_9.png
# Processed and saved: ../../data/preprocessed/97\crop_0.png
# Processed and saved: ../../data/preprocessed/97\crop_1.png
# Processed and saved: ../../data/preprocessed/97\crop_10.png
# Processed and saved: ../../data/preprocessed/97\crop_11.png
# Processed and saved: ../../data/preprocessed/97\crop_12.png
# Processed and saved: ../../data/preprocessed/97\crop_13.png
# Processed and saved: ../../data/preprocessed/97\crop_14.png
# Processed and saved: ../../data/preprocessed/97\crop_15.png
# Processed and saved: ../../data/preprocessed/97\crop_16.png
# Processed and saved: ../../data/preprocessed/97\crop_17.png
# Processed and saved: ../../data/preprocessed/97\crop_18.png
# Processed and saved: ../../data/preprocessed/97\crop_19.png
# Processed and saved: ../../data/preprocessed/97\crop_2.png
# Processed and saved: ../../data/preprocessed/97\crop_20.png
# Processed and saved: ../../data/preprocessed/97\crop_21.png
# Processed and saved: ../../data/preprocessed/97\crop_22.png
# Processed and saved: ../../data/preprocessed/97\crop_23.png
# Processed and saved: ../../data/preprocessed/97\crop_24.png
# Processed and saved: ../../data/preprocessed/97\crop_25.png
# Processed and saved: ../../data/preprocessed/97\crop_26.png
# Processed and saved: ../../data/preprocessed/97\crop_27.png
# Processed and saved: ../../data/preprocessed/97\crop_28.png
# Processed and saved: ../../data/preprocessed/97\crop_29.png
# Processed and saved: ../../data/preprocessed/97\crop_3.png
# Processed and saved: ../../data/preprocessed/97\crop_4.png
# Processed and saved: ../../data/preprocessed/97\crop_5.png
# Processed and saved: ../../data/preprocessed/97\crop_6.png
# Processed and saved: ../../data/preprocessed/97\crop_7.png
# Processed and saved: ../../data/preprocessed/97\crop_8.png
# Processed and saved: ../../data/preprocessed/97\crop_9.png
# Processed and saved: ../../data/preprocessed/98\crop_0.png
# Processed and saved: ../../data/preprocessed/98\crop_1.png
# Processed and saved: ../../data/preprocessed/98\crop_2.png
# Processed and saved: ../../data/preprocessed/98\crop_3.png
# Processed and saved: ../../data/preprocessed/98\crop_4.png
